# %%
print("Bronze:", spark.table("workspace.default.tweets_bronze").count())
print("Silver:", spark.table("workspace.default.tweets_silver").count())
print("Gold:  ", spark.table("workspace.default.tweets_gold").count())
print("Agg:   ", spark.table("workspace.default.gold_tweet_aggregations").count())

# Eyeball a few rows
spark.table("workspace.default.tweets_gold").select(
    "cleaned_text", "predicted_sentiment", "predicted_score", "sentiment_id", "predicted_sentiment_id"
).show(5, truncate=80)
